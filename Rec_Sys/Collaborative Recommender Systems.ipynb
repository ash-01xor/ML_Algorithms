# %% [markdown]
# ### Importing libraries:

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Reading data:

# %%
movies = pd.read_csv("Rec_Sys/movies.csv")
ratings = pd.read_csv("Rec_Sys/ratings.csv")

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
df = pd.merge(ratings,movies,on='movieId',how='inner')
df.head()
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0       1        1     4.0   964982703  Toy Story (1995)
# 1       5        1     4.0   847434962  Toy Story (1995)
# 2       7        1     4.5  1106635946  Toy Story (1995)
# 3      15        1     2.5  1510577970  Toy Story (1995)
# 4      17        1     4.5  1305696483  Toy Story (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1  Adventure|Animation|Children|Comedy|Fantasy
# 2  Adventure|Animation|Children|Comedy|Fantasy
# 3  Adventure|Animation|Children|Comedy|Fantasy
# 4  Adventure|Animation|Children|Comedy|Fantasy

# %% [markdown]
# ### EDA:
#
# - Filtering the dataset to deal with movies which has been rated by lot of people
# - This eases the way of working with data intially.

# %%
agg_ratings = df.groupby('title').agg(mean_rating = ('rating', 'mean'),
                number_of_ratings = ('rating', 'count')).reset_index()

# %%
ratings_75 = agg_ratings[agg_ratings['number_of_ratings']>75]

# %%
ratings_75
# Out:
#                                            title  mean_rating  \
# 74                  2001: A Space Odyssey (1968)     3.894495
# 104                                   300 (2007)     3.681250
# 207            Ace Ventura: Pet Detective (1994)     3.040373
# 208        Ace Ventura: When Nature Calls (1995)     2.727273
# 223                  Addams Family Values (1993)     3.101190
# ...                                          ...          ...
# 9433             Who Framed Roger Rabbit? (1988)     3.572165
# 9485  Willy Wonka & the Chocolate Factory (1971)     3.873950
# 9537                    Wizard of Oz, The (1939)     3.880435
# 9615                                X-Men (2000)     3.699248
# 9621                     X2: X-Men United (2003)     3.723684
#
#       number_of_ratings
# 74                  109
# 104                  80
# 207                 161
# 208                  88
# 223                  84
# ...                 ...
# 9433                 97
# 9485                119
# 9537                 92
# 9615                133
# 9621                 76
#
# [230 rows x 3 columns]

# %%
ratings_75.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 230 entries, 74 to 9621
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              230 non-null    object
#  1   mean_rating        230 non-null    float64
#  2   number_of_ratings  230 non-null    int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
ratings_75.sort_values(by='number_of_ratings',ascending=False).head()
# Out:
#                                  title  mean_rating  number_of_ratings
# 3158               Forrest Gump (1994)     4.164134                329
# 7593  Shawshank Redemption, The (1994)     4.429022                317
# 6865               Pulp Fiction (1994)     4.197068                307
# 7680  Silence of the Lambs, The (1991)     4.161290                279
# 5512                Matrix, The (1999)     4.192446                278

# %% [markdown]
# - Combing the data of movies with more than 75 people ratings.

# %%
df_75 = pd.merge(df,ratings_75[['title']],on='title',how='inner')
df_75.head()
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0       1        1     4.0   964982703  Toy Story (1995)
# 1       5        1     4.0   847434962  Toy Story (1995)
# 2       7        1     4.5  1106635946  Toy Story (1995)
# 3      15        1     2.5  1510577970  Toy Story (1995)
# 4      17        1     4.5  1305696483  Toy Story (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1  Adventure|Animation|Children|Comedy|Fantasy
# 2  Adventure|Animation|Children|Comedy|Fantasy
# 3  Adventure|Animation|Children|Comedy|Fantasy
# 4  Adventure|Animation|Children|Comedy|Fantasy

# %%
df_75.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28113 entries, 0 to 28112
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     28113 non-null  int64
#  1   movieId    28113 non-null  int64
#  2   rating     28113 non-null  float64
#  3   timestamp  28113 non-null  int64
#  4   title      28113 non-null  object
#  5   genres     28113 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Create user-item matrix:

# %%
ui_matrix = df_75.pivot_table(index='userId',columns='title',values='rating')
ui_matrix.head()
# Out:
# title   2001: A Space Odyssey (1968)  300 (2007)  \
# userId
# 1                                NaN         NaN
# 2                                NaN         NaN
# 3                                NaN         NaN
# 4                                NaN         NaN
# 5                                NaN         NaN
#
# title   Ace Ventura: Pet Detective (1994)  \
# userId
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     3.0
#
# title   Ace Ventura: When Nature Calls (1995)  Addams Family Values (1993)  \
# userId
# 1                                         NaN                          NaN
# 2                                         NaN                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
# 5                                         NaN                          3.0
#
# title   Airplane! (1980)  Aladdin (1992)  Alien (1979)  Aliens (1986)  \
# userId
# 1                    NaN             NaN           4.0            NaN
# 2                    NaN             NaN           NaN            NaN
# 3                    NaN             NaN           NaN            NaN
# 4                    5.0             4.0           NaN            NaN
# 5                    NaN             4.0           NaN            NaN
#
# title   Almost Famous (2000)  ...  WALL·E (2008)  Waterworld (1995)  \
# userId                        ...
# 1                        NaN  ...            NaN                NaN
# 2                        NaN  ...            NaN                NaN
# 3                        NaN  ...            NaN                NaN
# 4                        4.0  ...            NaN                NaN
# 5                        NaN  ...            NaN                NaN
#
# title   What's Eating Gilbert Grape (1993)  When Harry Met Sally... (1989)  \
# userId
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                      NaN                             NaN
# 5                                      NaN                             NaN
#
# title   While You Were Sleeping (1995)  Who Framed Roger Rabbit? (1988)  \
# userId
# 1                                  NaN                              5.0
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# 5                                  NaN                              NaN
#
# title   Willy Wonka & the Chocolate Factory (1971)  Wizard of Oz, The (1939)  \
# userId
# 1                                              5.0                       5.0
# 2                                              NaN                       NaN
# 3                                              NaN                       NaN
# 4                                              4.0                       5.0
# 5                                              NaN                       NaN
#
# title   X-Men (2000)  X2: X-Men United (2003)
# userId
# 1                5.0                      NaN
# 2                NaN                      NaN
# 3                NaN                      NaN
# 4                NaN                      NaN
# 5                NaN                      NaN
#
# [5 rows x 230 columns]

# %% [markdown]
# - normalizing the data inorder to make them comparable
#     - few movies have higher ratings and some movies arent rated.

# %%
matrix_norm = ui_matrix.subtract(ui_matrix.mean(axis=1), axis = 'rows')
matrix_norm.head()
# Out:
# title   2001: A Space Odyssey (1968)  300 (2007)  \
# userId
# 1                                NaN         NaN
# 2                                NaN         NaN
# 3                                NaN         NaN
# 4                                NaN         NaN
# 5                                NaN         NaN
#
# title   Ace Ventura: Pet Detective (1994)  \
# userId
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                    -0.5
#
# title   Ace Ventura: When Nature Calls (1995)  Addams Family Values (1993)  \
# userId
# 1                                         NaN                          NaN
# 2                                         NaN                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
# 5                                         NaN                         -0.5
#
# title   Airplane! (1980)  Aladdin (1992)  Alien (1979)  Aliens (1986)  \
# userId
# 1                    NaN             NaN     -0.381579            NaN
# 2                    NaN             NaN           NaN            NaN
# 3                    NaN             NaN           NaN            NaN
# 4               1.509804        0.509804           NaN            NaN
# 5                    NaN        0.500000           NaN            NaN
#
# title   Almost Famous (2000)  ...  WALL·E (2008)  Waterworld (1995)  \
# userId                        ...
# 1                        NaN  ...            NaN                NaN
# 2                        NaN  ...            NaN                NaN
# 3                        NaN  ...            NaN                NaN
# 4                   0.509804  ...            NaN                NaN
# 5                        NaN  ...            NaN                NaN
#
# title   What's Eating Gilbert Grape (1993)  When Harry Met Sally... (1989)  \
# userId
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                      NaN                             NaN
# 5                                      NaN                             NaN
#
# title   While You Were Sleeping (1995)  Who Framed Roger Rabbit? (1988)  \
# userId
# 1                                  NaN                         0.618421
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# 5                                  NaN                              NaN
#
# title   Willy Wonka & the Chocolate Factory (1971)  Wizard of Oz, The (1939)  \
# userId
# 1                                         0.618421                  0.618421
# 2                                              NaN                       NaN
# 3                                              NaN                       NaN
# 4                                         0.509804                  1.509804
# 5                                              NaN                       NaN
#
# title   X-Men (2000)  X2: X-Men United (2003)
# userId
# 1           0.618421                      NaN
# 2                NaN                      NaN
# 3                NaN                      NaN
# 4                NaN                      NaN
# 5                NaN                      NaN
#
# [5 rows x 230 columns]

# %% [markdown]
# ### Finding similar users:
# - we can either use
#     - pearson correlation
#     - cosine similarity

# %%
user_similarity = matrix_norm.T.corr()
user_similarity.head()
# Out:
# userId       1    2    3         4         5         6         7         8    \
# userId
# 1       1.000000  NaN  NaN  0.240346  0.180151 -0.439941 -0.180724  0.464277
# 2            NaN  1.0  NaN       NaN       NaN       NaN       NaN       NaN
# 3            NaN  NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 4       0.240346  NaN  NaN  1.000000 -0.398485  0.390831  0.706784  0.063888
# 5       0.180151  NaN  NaN -0.398485  1.000000 -0.013482  0.328889  0.028347
#
# userId       9         10   ...       601       602       603       604  \
# userId                      ...
# 1       0.904534 -0.037987  ...  0.091574  0.254514 -0.050567 -0.500000
# 2            NaN -0.500000  ... -0.559793       NaN -1.000000       NaN
# 3            NaN       NaN  ...       NaN       NaN       NaN       NaN
# 4            NaN  0.541119  ... -0.348903  0.561435  0.142054 -0.158114
# 5            NaN -0.777714  ...  0.000000  0.209004  0.190885  0.063383
#
# userId       605       606       607       608       609       610
# userId
# 1       0.050292  0.202870  0.165287  0.166715 -0.175412 -0.043875
# 2            NaN  0.583333       NaN -0.229416       NaN  0.730740
# 3            NaN       NaN       NaN       NaN       NaN       NaN
# 4       0.518328 -0.008023  0.053755 -0.339963       NaN -0.226816
# 5      -0.290482  0.305477  0.228218  0.211898  0.384111  0.040582
#
# [5 rows x 602 columns]

# %%
# Pick a user ID
picked_userid = 4# Remove picked user ID from the candidate list
user_similarity.drop(index=picked_userid, inplace=True)# Take a look at the data
user_similarity.head()
# Out:
# userId       1    2    3         4         5         6         7         8    \
# userId
# 1       1.000000  NaN  NaN  0.240346  0.180151 -0.439941 -0.180724  0.464277
# 2            NaN  1.0  NaN       NaN       NaN       NaN       NaN       NaN
# 3            NaN  NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 5       0.180151  NaN  NaN -0.398485  1.000000 -0.013482  0.328889  0.028347
# 6      -0.439941  NaN  NaN  0.390831 -0.013482  1.000000  0.000000 -0.144641
#
# userId       9         10   ...       601       602       603       604  \
# userId                      ...
# 1       0.904534 -0.037987  ...  0.091574  0.254514 -0.050567 -0.500000
# 2            NaN -0.500000  ... -0.559793       NaN -1.000000       NaN
# 3            NaN       NaN  ...       NaN       NaN       NaN       NaN
# 5            NaN -0.777714  ...  0.000000  0.209004  0.190885  0.063383
# 6            NaN  0.957427  ... -0.292770  0.060433 -0.251331 -0.034298
#
# userId       605       606       607       608       609       610
# userId
# 1       0.050292  0.202870  0.165287  0.166715 -0.175412 -0.043875
# 2            NaN  0.583333       NaN -0.229416       NaN  0.730740
# 3            NaN       NaN       NaN       NaN       NaN       NaN
# 5      -0.290482  0.305477  0.228218  0.211898  0.384111  0.040582
# 6       0.066229 -0.247519  0.486395 -0.218900  0.193649 -0.035858
#
# [5 rows x 602 columns]

# %%
n=5 #finding similar number of user
user_threshold = 0.35 #user similarity threshold
similar_users = user_similarity[user_similarity[picked_userid]>user_threshold][picked_userid].sort_values(ascending=False)[:n]

# %%
print(f"the similar users for:{picked_userid}:\n{similar_users}")
# Out:
# the similar users for:4:
# userId
# 162    1.0
# 299    1.0
# 544    1.0
# 568    1.0
# 473    1.0
# Name: 4, dtype: float64

# %% [markdown]
# - removing the movies watched by the user
# - keeping only the movies watched by similar users.

# %%
picked_userid_watched = matrix_norm[matrix_norm.index == picked_userid].dropna(axis=1, how='all')
picked_userid_watched
# Out:
# title   Airplane! (1980)  Aladdin (1992)  Almost Famous (2000)  \
# userId
# 4               1.509804        0.509804              0.509804
#
# title   Amadeus (1984)  American Beauty (1999)  \
# userId
# 4             0.509804                1.509804
#
# title   Austin Powers: International Man of Mystery (1997)  \
# userId
# 4                                                0.509804
#
# title   Austin Powers: The Spy Who Shagged Me (1999)  \
# userId
# 4                                           0.509804
#
# title   Beauty and the Beast (1991)  Beetlejuice (1988)  \
# userId
# 4                         -0.490196            1.509804
#
# title   Being John Malkovich (1999)  ...  Sixth Sense, The (1999)  \
# userId                               ...
# 4                          0.509804  ...                 0.509804
#
# title   Sleepless in Seattle (1993)  Stand by Me (1986)  \
# userId
# 4                         -2.490196            0.509804
#
# title   Star Wars: Episode I - The Phantom Menace (1999)  \
# userId
# 4                                              -2.490196
#
# title   Star Wars: Episode IV - A New Hope (1977)  \
# userId
# 4                                        1.509804
#
# title   Star Wars: Episode V - The Empire Strikes Back (1980)  \
# userId
# 4                                                1.509804
#
# title   There's Something About Mary (1998)  \
# userId
# 4                                 -0.490196
#
# title   Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  \
# userId
# 4                                       -1.490196
#
# title   Willy Wonka & the Chocolate Factory (1971)  Wizard of Oz, The (1939)
# userId
# 4                                         0.509804                  1.509804
#
# [1 rows x 51 columns]

# %%
similar_user_movies = matrix_norm[matrix_norm.index.isin(similar_users.index)].dropna(axis=1, how='all')
similar_user_movies
# Out:
# title   Alien (1979)  Almost Famous (2000)  American History X (1998)  \
# userId
# 162              NaN                   NaN                        NaN
# 299        -0.636364                   NaN                        NaN
# 473              NaN                   0.5                        0.0
# 544              NaN                   NaN                        NaN
# 568              NaN                   NaN                        NaN
#
# title   Apollo 13 (1995)  Batman (1989)  Batman Forever (1995)  \
# userId
# 162               -0.125         -0.125                 -0.125
# 299                  NaN            NaN                    NaN
# 473                  NaN            NaN                    NaN
# 544                  NaN            NaN                    NaN
# 568                  NaN            NaN                    NaN
#
# title   Broken Arrow (1996)  Casino (1995)  Dances with Wolves (1990)  \
# userId
# 162                     NaN          0.875                     -0.125
# 299                     NaN            NaN                        NaN
# 473                     NaN            NaN                        NaN
# 544                   -0.25            NaN                        NaN
# 568                     NaN            NaN                        NaN
#
# title   Donnie Darko (2001)  ...  Shining, The (1980)  \
# userId                       ...
# 162                     NaN  ...                  NaN
# 299                     NaN  ...             0.363636
# 473                    -0.5  ...                  NaN
# 544                     NaN  ...                  NaN
# 568                     NaN  ...                  NaN
#
# title   Silence of the Lambs, The (1991)  Star Trek: First Contact (1996)  \
# userId
# 162                                  NaN                              NaN
# 299                                  NaN                              NaN
# 473                                  NaN                              NaN
# 544                                  NaN                             0.75
# 568                                  0.5                              NaN
#
# title   Star Wars: Episode I - The Phantom Menace (1999)  Toy Story (1995)  \
# userId
# 162                                                  NaN               NaN
# 299                                            -1.636364               NaN
# 473                                                  NaN               NaN
# 544                                                  NaN             -1.25
# 568                                                  NaN               NaN
#
# title   Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Twister (1996)  \
# userId
# 162                                           NaN             NaN
# 299                                           NaN             NaN
# 473                                           NaN             NaN
# 544                                         -1.25            0.75
# 568                                           NaN             NaN
#
# title   Usual Suspects, The (1995)  What's Eating Gilbert Grape (1993)  \
# userId
# 162                         -0.125                              -1.125
# 299                            NaN                                 NaN
# 473                            NaN                                 NaN
# 544                            NaN                                 NaN
# 568                          0.500                                 NaN
#
# title   X-Men (2000)
# userId
# 162              NaN
# 299         0.363636
# 473              NaN
# 544              NaN
# 568              NaN
#
# [5 rows x 43 columns]

# %%
similar_user_movies.drop(picked_userid_watched.columns,axis=1, inplace=True, errors='ignore')
similar_user_movies
# Out:
# title   Alien (1979)  American History X (1998)  Apollo 13 (1995)  \
# userId
# 162              NaN                        NaN            -0.125
# 299        -0.636364                        NaN               NaN
# 473              NaN                        0.0               NaN
# 544              NaN                        NaN               NaN
# 568              NaN                        NaN               NaN
#
# title   Batman (1989)  Batman Forever (1995)  Broken Arrow (1996)  \
# userId
# 162            -0.125                 -0.125                  NaN
# 299               NaN                    NaN                  NaN
# 473               NaN                    NaN                  NaN
# 544               NaN                    NaN                -0.25
# 568               NaN                    NaN                  NaN
#
# title   Casino (1995)  Dances with Wolves (1990)  Donnie Darko (2001)  \
# userId
# 162             0.875                     -0.125                  NaN
# 299               NaN                        NaN                  NaN
# 473               NaN                        NaN                 -0.5
# 544               NaN                        NaN                  NaN
# 568               NaN                        NaN                  NaN
#
# title   Eternal Sunshine of the Spotless Mind (2004)  ...  Rain Man (1988)  \
# userId                                                ...
# 162                                              NaN  ...              NaN
# 299                                              NaN  ...         0.363636
# 473                                              0.5  ...              NaN
# 544                                              NaN  ...              NaN
# 568                                              NaN  ...              NaN
#
# title   Schindler's List (1993)  Shawshank Redemption, The (1994)  \
# userId
# 162                       0.875                             0.875
# 299                         NaN                               NaN
# 473                         NaN                             0.500
# 544                         NaN                               NaN
# 568                         NaN                               NaN
#
# title   Shining, The (1980)  Star Trek: First Contact (1996)  \
# userId
# 162                     NaN                              NaN
# 299                0.363636                              NaN
# 473                     NaN                              NaN
# 544                     NaN                             0.75
# 568                     NaN                              NaN
#
# title   Toy Story (1995)  Twister (1996)  Usual Suspects, The (1995)  \
# userId
# 162                  NaN             NaN                      -0.125
# 299                  NaN             NaN                         NaN
# 473                  NaN             NaN                         NaN
# 544                -1.25            0.75                         NaN
# 568                  NaN             NaN                       0.500
#
# title   What's Eating Gilbert Grape (1993)  X-Men (2000)
# userId
# 162                                 -1.125           NaN
# 299                                    NaN      0.363636
# 473                                    NaN           NaN
# 544                                    NaN           NaN
# 568                                    NaN           NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Recommend Items:

# %%
item_score = {}
for i in similar_user_movies.columns:
  # Get the ratings for movie i
  movie_rating = similar_user_movies[i]
  # Creating a variable to store the score
  total = 0
  # Create a variable to store the number of scores
  count = 0
  # Loop through similar users
  for u in similar_users.index:
    # If the movie has rating
    if pd.isna(movie_rating[u]) == False:
      # Score is the sum of user similarity score multiply by the movie rating
      score = similar_users[u] * movie_rating[u]
      # Add the score to the total score for the movie so far
      total += score
      # Add 1 to the count
      count +=1
  # Get the average score for the item
  item_score[i] = total / count# Convert dictionary to pandas dataframe
item_score = pd.DataFrame(item_score.items(), columns=['movie', 'movie_score'])
    
# Sort the movies by score
ranked_item_score = item_score.sort_values(by='movie_score', ascending=False)# Select top m movies
m = 10
ranked_item_score.head(m)
# Out:
#                                            movie  movie_score
# 13                              Gladiator (2000)     1.363636
# 6                                  Casino (1995)     0.875000
# 25                       Schindler's List (1993)     0.875000
# 21                     Mr. Holland's Opus (1995)     0.812500
# 14          Independence Day (a.k.a. ID4) (1996)     0.750000
# 28               Star Trek: First Contact (1996)     0.750000
# 30                                Twister (1996)     0.750000
# 26              Shawshank Redemption, The (1994)     0.687500
# 10                           Forrest Gump (1994)     0.687500
# 9   Eternal Sunshine of the Spotless Mind (2004)     0.500000
